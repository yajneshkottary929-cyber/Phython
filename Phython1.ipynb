# %%
name = "Yajnesh"
age = 18
height = 1.70

print(name, age, height)
# Out:
# Yajnesh 18 1.7

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

print(type(num1))
print(type(num2))
# Out:
# Enter first number:  Yajnesh
# Enter second number:  Kottary
# <class 'str'>
# <class 'str'>

# %%
price = 500
is_available = True

print(price, type(price))
print(is_available, type(is_available))
# Out:
# 500 <class 'int'>
# True <class 'bool'>

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name, "you are", age, "years old.")
# Out:
# Enter your name:  Yajnesh
# Enter your age:  18
# Hello Yajnesh you are 18 years old.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum =", num1 + num2)
print("Difference =", num1 - num2)
print("Product =", num1 * num2)
print("Quotient =", num1 / num2)
# Out:
# Enter first number:  70
# Enter second number:  7
# Sum = 77.0
# Difference = 63.0
# Product = 490.0
# Quotient = 10.0

# %%
price = float(input("Enter price: "))
quantity = int(input("Enter quantity: "))

total_cost = price * quantity

print("Total cost =", total_cost)
# Out:
# Enter price:  700
# Enter quantity:  7
# Total cost = 4900.0

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
print("Floor Division =", a // b)
print("Modulus =", a % b)
print("Power =", a ** b)
# Out:
# Enter first number:  707
# Enter second number:  77
# Addition = 784.0
# Subtraction = 630.0
# Multiplication = 54439.0
# Division = 9.181818181818182
# Floor Division = 9.0
# Modulus = 14.0
# Power = 2.542698473769549e+219

# %%
cost_price = 1000
selling_price = 1200

profit = selling_price - cost_price

print("Profit =", profit)
# Out:
# Profit = 200

# %%
cost_price = 1500
selling_price = 1300

loss = cost_price - selling_price

print("Loss =", loss)
# Out:
# Loss = 200

# %%
price = 2000
discount_rate = 20

discount = price * discount_rate / 100
final_price = price - discount

print("Discount =", discount)
print("Final price =", final_price)
# Out:
# Discount = 400.0
# Final price = 1600.0

# %%
cost_price = float(input("Enter cost price: "))
selling_price = float(input("Enter selling price: "))

if selling_price > cost_price:
    profit = selling_price - cost_price
    profit_percent = (profit / cost_price) * 100

    print("Profit =", profit)
    print("Profit % =", profit_percent)

elif selling_price < cost_price:
    loss = cost_price - selling_price
    loss_percent = (loss / cost_price) * 100

    print("Loss =", loss)
    print("Loss % =", loss_percent)

else:
    print("No profit, no loss")
# Out:
# Enter cost price:  7000
# Enter selling price:  1700
# Loss = 5300.0
# Loss % = 75.71428571428571

# %%
price = float(input("Enter price: "))
gst_rate = float(input("Enter GST rate: "))

gst_amount = price * gst_rate / 100
final_price = price + gst_amount

print("GST amount =", gst_amount)
print("Final price =", final_price)
# Out:
# Enter price:  7070
# Enter GST rate:  17
# GST amount = 1201.9
# Final price = 8271.9

# %%
income = float(input("Enter annual income: "))

if income <= 500000:
    tax = 0
else:
    tax = (income - 500000) * 10 / 100

print("Tax amount =", tax)
# Out:
# Enter annual income:  7700
# Tax amount = 0

# %%
cost_price = float(input("Enter cost price: "))
selling_price = float(input("Enter selling price: "))
gst_rate = float(input("Enter GST rate: "))
discount_rate = float(input("Enter discount rate: "))

# Profit or Loss
if selling_price > cost_price:
    profit = selling_price - cost_price
    print("Profit =", profit)

elif selling_price < cost_price:
    loss = cost_price - selling_price
    print("Loss =", loss)

else:
    print("No profit, no loss")

# Discount
discount = selling_price * discount_rate / 100
price_after_discount = selling_price - discount

print("Price after discount =", price_after_discount)

# GST
gst_amount = price_after_discount * gst_rate / 100
final_price = price_after_discount + gst_amount

print("GST amount =", gst_amount)
print("Final price =", final_price)
# Out:
# Enter cost price:  17000
# Enter selling price:  77000
# Enter GST rate:  7
# Enter discount rate:  17
# Profit = 60000.0
# Price after discount = 63910.0
# GST amount = 4473.7
# Final price = 68383.7
